# %% [markdown]
# ## Problem 1:

# %% [markdown]
# # a) Matrix Transpose
#  $A = \begin{bmatrix}
#   a & b  \\
#   c & d  \\
#  \end{bmatrix}$
# #The transpose of A is:
# $ A ^{T} = \begin{bmatrix}
#   a & c  \\
#   b & d  \\
#  \end{bmatrix}$
#  # What is the transpose of x?
# $ x = \begin{bmatrix}
#   1 & 2 & 3 \\
#   4 & 5 & 6 \\
#   7 & 8 & 9 \\
#  \end{bmatrix}$

# %% [markdown]
# # b) Matrix Vector Product
# $\begin{bmatrix}
#   1 & -1  \\
#   0 & 2  \\
#  \end{bmatrix} *
#  \begin{bmatrix}
#   2 \\
#   1 \\
#  \end{bmatrix} = $

# %% [markdown]
# ## c) Matrix Inverse
# $ A = \begin{bmatrix}
#   a & b  \\
#   c & d  \\
#  \end{bmatrix}$
#  # The inverse of A is:
#  $\frac{1}{ad - bc} *
#  \begin{bmatrix}
#   d & -b  \\
#   -c & a  \\
#  \end{bmatrix}$
# # What is the inverse of x?
# $ x = \begin{bmatrix}
#   1 & -1  \\
#   -0 & 2  \\
#  \end{bmatrix}$

# %% [markdown]
# ## Problem 1:
# # a)
# $\begin{pmatrix}
#   1 & 2 & 3 \\
#   4 & 5 & 6 \\
#   7 & 8 & 9
#  \end{pmatrix}^ {T}
#  =
#  \begin{pmatrix}
#   1 & 4 & 7 \\
#   2 & 5 & 8 \\
#   3 & 6 & 9
#  \end{pmatrix}$
# # b)
# $\begin{pmatrix}
#   1 & -1  \\
#   0 & 2  \\
#  \end{pmatrix}
# \begin{pmatrix}
#   2 \\
#   1
#  \end{pmatrix}
#  = \begin{pmatrix}
#  2 \\
#  1
#  \end{pmatrix} $
#
#
#
# # c)
# $\begin{pmatrix}
#   1 & -1  \\
#   0 & 2  \\
#  \end{pmatrix} ^ {-1}
#  = \begin{pmatrix}
#   1 & {\frac{1}{2}}  \\
#   0 & {\frac{1}{2}}  \\
#  \end{pmatrix}$
#
# # d)
# Given:
#
# $\begin{array}{lll}
#        & x & y    \\
# Data 1 & 1 & 3.1  \\
# Data 2 & 2 & 4.8  \\
# Data 3 & 3 & 7.2  \\
# Data 4 & 4 & 8.6  \\
# Data 5 & 5 & 11.1
# \end{array}$
#
# Using equation from lecture slides:
#
# $ \theta = (X^{T}X)^{-1}X^{T}Y$
#
# Design matrix (X) and Y value matrix:
#
# $ X =
# \begin{pmatrix}
# 1 & 1 \\
# 1 & 2 \\
# 1 & 3 \\
# 1 & 4 \\
# 1 & 5
# \end{pmatrix}
# Y =
# \begin{pmatrix}
# 3.1 \\ 4.8 \\ 7.2 \\ 8.6 \\ 11.1
# \end{pmatrix}
# $
#
# $
# X^T =
# \begin{pmatrix}
# 1 & 1 & 1 & 1 & 1 \\
# 1 & 2 & 3 & 4 & 5
# \end{pmatrix}
# $
#
# $ (X^TX) = (
#   \begin{pmatrix}
# 1 & 1 & 1 & 1 & 1 \\
# 1 & 2 & 3 & 4 & 5
# \end{pmatrix}
# \begin{pmatrix}
# 1 & 1 \\
# 1 & 2 \\
# 1 & 3 \\
# 1 & 4 \\
# 1 & 5
# \end{pmatrix}) =
# \begin{pmatrix}
# 5 & 15 \\
# 15 & 55
# \end{pmatrix}$
#
# $(X^TX)^{-1} =
# \begin{pmatrix}
# 5 & 15 \\
# 15 & 55
# \end{pmatrix} ^ {-1} = \frac{1} {275 - 225}
# \begin{pmatrix}
# 55 & -15 \\
# -15 & 5
# \end{pmatrix} =
# \begin{pmatrix}
# \frac{11} {10} & \frac{-3} {10} \\
# \frac{-3} {10} & \frac{1} {10}
# \end{pmatrix}$
#
# $X^{T}Y =
# \begin{pmatrix}
# 1 & 1 & 1 & 1 & 1 \\
# 1 & 2 & 3 & 4 & 5
# \end{pmatrix}
# \begin{pmatrix}
# 3.1 \\ 4.8 \\ 7.2 \\ 8.6 \\ 11.1
# \end{pmatrix}
#  =
# \begin{pmatrix}
# 34.8 \\ 124.2
# \end{pmatrix}
# $
#
# $(X^{T}X)^{-1}X^{T}Y =
# \begin{pmatrix}
# \frac{11} {10} & \frac{-3} {10} \\
# \frac{-3} {10} & \frac{1} {10}
# \end{pmatrix}
# \begin{pmatrix}
# 34.8 \\ 124.2
# \end{pmatrix}
#  =
#  \begin{pmatrix}
#  1.02 \\ 1.98
#  \end{pmatrix}
# $
#
# $\theta_0 = 1.02$
#
# $\theta_1 = 1.98$
